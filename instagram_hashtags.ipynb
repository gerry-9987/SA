# %%
import pandas as pd
import numpy as np
import json

# %%
hashtags = pd.read_csv('instagram_hashtag_results_18Mar.csv')

# %%
hashtags.head()
# Out:
#                                     postUrl  \
# 0  https://www.instagram.com/p/CbKYWL8AuAF/
# 1  https://www.instagram.com/p/CbK9hAvhxjC/
# 2  https://www.instagram.com/p/CbKJdGUj_gg/
# 3  https://www.instagram.com/p/CbHDHKrPN1X/
# 4  https://www.instagram.com/p/CbIAdAXupdV/
#
#                                        profileUrl              username  \
# 0         https://www.instagram.com/leassteinwelt         leassteinwelt
# 1        https://www.instagram.com/awakenstardust        awakenstardust
# 2   https://www.instagram.com/praktijk_matricaria   praktijk_matricaria
# 3  https://www.instagram.com/nickycrystcollection  nickycrystcollection
# 4     https://www.instagram.com/sacredsoulfulshop     sacredsoulfulshop
#
#                   fullName  commentCount  likeCount                   pubDate  \
# 0      💎Kristall Paradies💎             9        501  2022-03-16T10:58:16.000Z
# 1    Bring Love to People❤            26       1157  2022-03-16T16:23:03.000Z
# ...

# %%
hashtags.tail()
# Out:
#                                        postUrl  \
# 3911  https://www.instagram.com/p/Ca5WLPNBANU/
# 3912  https://www.instagram.com/p/Ca5WD0EBxVw/
# 3913  https://www.instagram.com/p/Ca5UPA2hVWG/
# 3914  https://www.instagram.com/p/Ca5QCWShv5v/
# 3915  https://www.instagram.com/p/Ca5Pd2QhAqA/
#
#                                           profileUrl              username  \
# 3911   https://www.instagram.com/crystal_stone_agate   crystal_stone_agate
# 3912   https://www.instagram.com/crystal_stone_agate   crystal_stone_agate
# 3913  https://www.instagram.com/internationalgemshop  internationalgemshop
# 3914     https://www.instagram.com/ervina_crystal123     ervina_crystal123
# 3915     https://www.instagram.com/ervina_crystal123     ervina_crystal123
#
#                    fullName  commentCount  likeCount  \
# 3911    Crystal_Stone_Agate             0          5
# 3912    Crystal_Stone_Agate             0          6
# 3913  International Gemshop             0         13
# ...

# %%
hashtags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   postUrl        4000 non-null   object
#  1   profileUrl     4000 non-null   object
#  2   username       4000 non-null   object
#  3   fullName       3854 non-null   object
#  4   commentCount   4000 non-null   int64
#  5   likeCount      4000 non-null   int64
#  6   pubDate        4000 non-null   object
#  7   description    3997 non-null   object
#  8   imgUrl         3638 non-null   object
#  9   postId         4000 non-null   int64
#  10  ownerId        4000 non-null   int64
#  11  type           4000 non-null   object
#  12  query          4000 non-null   object
#  13  timestamp      4000 non-null   object
#  14  location       881 non-null    object
#  15  isSidecar      4000 non-null   bool
#  16  sidecarMedias  1537 non-null   float64
# ...

# %%
hashtags.drop_duplicates(subset=['postId'], inplace=True)

# %%
hashtags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3916 entries, 0 to 3999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   postUrl        3916 non-null   object
#  1   profileUrl     3916 non-null   object
#  2   username       3916 non-null   object
#  3   fullName       3772 non-null   object
#  4   commentCount   3916 non-null   int64
#  5   likeCount      3916 non-null   int64
#  6   pubDate        3916 non-null   object
#  7   description    3913 non-null   object
#  8   imgUrl         3571 non-null   object
#  9   postId         3916 non-null   int64
#  10  ownerId        3916 non-null   int64
#  11  type           3916 non-null   object
#  12  query          3916 non-null   object
#  13  timestamp      3916 non-null   object
#  14  location       859 non-null    object
#  15  isSidecar      3916 non-null   bool
#  16  sidecarMedias  1504 non-null   float64
# ...

# %%
hashtags.to_csv("instagram_hashtag_results_18Mar_cleaned.csv", index=False)

# %%
hashtags = pd.read_csv('instagram_hashtag_results_18Mar_cleaned.csv')

# %%
crystalsg = hashtags.loc[hashtags['query'] == "#crystalsg"]

# %%
crystalsg
# Out:
#                                        postUrl  \
# 1918  https://www.instagram.com/p/CaJQO5HPHO1/
# 1919  https://www.instagram.com/p/CZMdip8PCzX/
# 1920  https://www.instagram.com/p/CZviYgxvmz7/
# 1921  https://www.instagram.com/p/CUaL0oNPhEm/
# 1922  https://www.instagram.com/p/CW76Q2ZPwI9/
# ...                                        ...
# 3911  https://www.instagram.com/p/Ca5WLPNBANU/
# 3912  https://www.instagram.com/p/Ca5WD0EBxVw/
# 3913  https://www.instagram.com/p/Ca5UPA2hVWG/
# 3914  https://www.instagram.com/p/Ca5QCWShv5v/
# 3915  https://www.instagram.com/p/Ca5Pd2QhAqA/
#
#                                           profileUrl              username  \
# 1918        https://www.instagram.com/petalsofarosez        petalsofarosez
# 1919          https://www.instagram.com/princessezyt          princessezyt
# 1920  https://www.instagram.com/moonwanderer.est2020  moonwanderer.est2020
# 1921           https://www.instagram.com/crystalliac           crystalliac
# ...

# %%
crystalsg.to_csv("instagram_hashtag_results_crystalsg_cleaned.csv", index=False)

# %%
desc = hashtags["description"]

# %%
desc
# Out:
# 0       Wir haben schon die letzten Tage super fleißig...
# 1       Drop a 👁️ if you can relate\nFollow @awakensta...
# 2       Spirit kwarts 💕\nEindelijk! Na een lange zoekt...
# 3       Beautiful pink amethyst freedom from @elo.di_ ...
# 4       We’re you able to scoop up some Orca Agate las...
#                               ...
# 1913    Come visit me this Saturday at the @tacomacomm...
# 1914    March Madness SALE 40% OFF \n\n🌿Shop Link @bre...
# 1915    🌈 tear-drop oplaite earrings 🌈\n\nSpring sale ...
# 1916    A few blue kyanite rings. A wonderful cleansin...
# 1917    🌈🎉🌙⭐Super beautiful stone, crinoids fossils!  ...
# Name: description, Length: 1918, dtype: object

# %%
hashtags["hashtags"] = desc.str.split()
hashtags["hashtags"]
# Out:
# 0       [Wir, haben, schon, die, letzten, Tage, super,...
# 1       [Drop, a, 👁️, if, you, can, relate, Follow, @a...
# 2       [Spirit, kwarts, 💕, Eindelijk!, Na, een, lange...
# 3       [Beautiful, pink, amethyst, freedom, from, @el...
# 4       [We’re, you, able, to, scoop, up, some, Orca, ...
#                               ...
# 1913    [Come, visit, me, this, Saturday, at, the, @ta...
# 1914    [March, Madness, SALE, 40%, OFF, 🌿Shop, Link, ...
# 1915    [🌈, tear-drop, oplaite, earrings, 🌈, Spring, s...
# 1916    [A, few, blue, kyanite, rings., A, wonderful, ...
# 1917    [🌈🎉🌙⭐Super, beautiful, stone,, crinoids, fossi...
# Name: hashtags, Length: 1918, dtype: object

# %%
hashtags['hashtags'].isnull().values.any()
# Out:
# True

# %%
hashtags['hashtags'] = hashtags['hashtags'].apply(lambda d: d if isinstance(d, list) else [])

# %%
hashtags['hashtags'].isnull().values.any()
# Out:
# False

# %%
hashtag_col = hashtags["hashtags"]

# %%
hashtag_col = hashtag_col.apply(lambda x: [w.lower() for w in x])
hashtag_col
# Out:
# 0       [wir, haben, schon, die, letzten, tage, super,...
# 1       [drop, a, 👁️, if, you, can, relate, follow, @a...
# 2       [spirit, kwarts, 💕, eindelijk!, na, een, lange...
# 3       [beautiful, pink, amethyst, freedom, from, @el...
# 4       [we’re, you, able, to, scoop, up, some, orca, ...
#                               ...
# 1913    [come, visit, me, this, saturday, at, the, @ta...
# 1914    [march, madness, sale, 40%, off, 🌿shop, link, ...
# 1915    [🌈, tear-drop, oplaite, earrings, 🌈, spring, s...
# 1916    [a, few, blue, kyanite, rings., a, wonderful, ...
# 1917    [🌈🎉🌙⭐super, beautiful, stone,, crinoids, fossi...
# Name: hashtags, Length: 1918, dtype: object

# %%
hashtags['hashtags_str'] = [','.join(map(str, l)) for l in hashtags['hashtags']]

# %%
hashtags['hashtags_str']
# Out:
# 0       Wir,haben,schon,die,letzten,Tage,super,fleißig...
# 1       Drop,a,👁️,if,you,can,relate,Follow,@awakenstar...
# 2       Spirit,kwarts,💕,Eindelijk!,Na,een,lange,zoekto...
# 3       Beautiful,pink,amethyst,freedom,from,@elo.di_,...
# 4       We’re,you,able,to,scoop,up,some,Orca,Agate,las...
#                               ...
# 1913    Come,visit,me,this,Saturday,at,the,@tacomacomm...
# 1914    March,Madness,SALE,40%,OFF,🌿Shop,Link,@breezyd...
# 1915    🌈,tear-drop,oplaite,earrings,🌈,Spring,sale,Mar...
# 1916    A,few,blue,kyanite,rings.,A,wonderful,cleansin...
# 1917    🌈🎉🌙⭐Super,beautiful,stone,,crinoids,fossils!,O...
# Name: hashtags_str, Length: 1918, dtype: object

# %%
hashtags_str = hashtags['hashtags_str']

# %%
hashtags[hashtags_str.str.contains("Singapore")]
# Out:
#                                      postUrl  \
# 53  https://www.instagram.com/p/CbL7J_9vI7t/
#
#                                    profileUrl         username  \
# 53  https://www.instagram.com/galorecrystalsg  galorecrystalsg
#
#               fullName  commentCount  likeCount                   pubDate  \
# 53  crystals galore-SG             0          0  2022-03-17T01:21:40.000Z
#
#                                           description  \
# 53  Such a cool piece of ocean Jasper...it looks l...
#
#                                                imgUrl               postId  \
# 53  https://scontent-yyz1-1.cdninstagram.com/v/t51...  2795588165614472941
#
#     ...      type      query                 timestamp location isSidecar  \
# 53  ...  Carousel  #crystals  2022-03-17T01:27:21.812Z      NaN      True
#
#     sidecarMedias  videoUrl viewCount  \
# 53            2.0       NaN       NaN
#
#                                              hashtags  \
# ...

# %%
# for index, value in hashtag_col.items():
#     # print(index, value)
#     for word in value:
#         word = word.lower()
#         print(word)
# # hashtag_col
# Out:
# wir
# haben
# schon
# die
# letzten
# tage
# super
# fleißig
# daran
# gearbeitet
# den
# mega
# restock
# vorzubereiten🔥
# es
# wird
# diesmal
# über
# 1000
# neue
# artikel
# geben
# von
# kugeln
# bis
# zu
# türmen,
# clustern,
# teelicht
# haltern,
# rostücken,
# ohrringen,
# kettenanhängern,
# handsteinen,
# figuren,
# xxl
# kristallen,
# schalen
# und
# flaschen,
# räucherwerk
# und
# viel
# mehr😍😍
# das
# shop
# update
# findet
# am
# sonntag
# um
# 18:00
# uhr
# statt
# und
# ich
# möchte
# noch
# mal
# darauf
# hinweisen
# dass
# es
# vermutlich
# ziemlich
# stark
# besucht
# sein
# wird
# und
# dass
# ihr
# gerne
# mehrfach
# bestellen
# dürft
# um
# eure
# lieblingsstücke
# zu
# sichern❤️
# der
# warenkorb
# kann
# jederzeit
# von
# jemand
# anderen
# weg
# gekauft
# werden
# da
# man
# leider
# bei
# dem
# webseiten
# anbieter
# nicht
# denwarenkorb
# reservieren
# kann😭❤️
# wenn
# ihr
# mehrfach
# bestellt
# ist
# es
# auch
# nicht
# schlimm
# wenn
# ihr
# das
# ...

# %%
# # new_col = []
# for (idx, row) in hashtags.iterrows():
#     hashtags_row = row.loc['hashtags']
#     new_row = []
#     for word in hashtags_row:
#         word = word.lower()
#         new_row.append(word)
#         # print(word)
#     # new_col.append(new_row)
#     # print(new_row)
#     # print(hashtags.loc[idx, 'hashtags'])
#     hashtags.loc[idx, 'hashtags'] = new_row
#     # print(hashtags_col)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-b007b6670183> in <module>
#      10     # print(new_row)
#      11     # print(hashtags.loc[idx, 'hashtags'])
# ---> 12     hashtags.loc[idx, 'hashtags'] = new_row
#      13     # print(hashtags_col)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1728         if take_split_path:
#    1729             # We have to operate column-wise
# -> 1730             self._setitem_with_indexer_split_path(indexer, value, name)
#    1731         else:
# ...

# %%
# for (colname, colval) in hashtags.iteritems():
#     if colname == "hashtags":
#         for lst in colval:
#             for word in lst:
#                 # print(word)
#                 word = word.lower()
#         print(colval)
# Out:
# 0       [Wir, haben, schon, die, letzten, Tage, super,...
# 1       [Drop, a, 👁️, if, you, can, relate, Follow, @a...
# 2       [Spirit, kwarts, 💕, Eindelijk!, Na, een, lange...
# 3       [Beautiful, pink, amethyst, freedom, from, @el...
# 4       [We’re, you, able, to, scoop, up, some, Orca, ...
#                               ...
# 1913    [Come, visit, me, this, Saturday, at, the, @ta...
# 1914    [March, Madness, SALE, 40%, OFF, 🌿Shop, Link, ...
# 1915    [🌈, tear-drop, oplaite, earrings, 🌈, Spring, s...
# 1916    [A, few, blue, kyanite, rings., A, wonderful, ...
# 1917    [🌈🎉🌙⭐Super, beautiful, stone,, crinoids, fossi...
# Name: hashtags, Length: 1918, dtype: object

# %%
#NOT WORKING - used phantom buster

# %%
data = {'index':[], 'date':[], 'caption':[], 'comments':[]}

import instaloader
import numpy as np
import pandas as pd
import time
from datetime import datetime
from itertools import dropwhile, takewhile
import os


L = instaloader.Instaloader()
USER = ''
PASSWORD = ''

L.login(USER, PASSWORD)

# posts = instaloader.Hashtag.from_name(L.context, "jam.stones").get_posts()
posts = instaloader.Hashtag.from_name(L.context, "crystals").get_posts()

# Tracing backwards from today
SINCE = datetime(2022, 3, 15) # February 22, 2022
UNTIL = datetime(2022, 1, 1) # January 22, 2022

for post in takewhile(lambda p: p.date > UNTIL, dropwhile(lambda p: p.date > SINCE, posts)):
    print(post.date)
    L.download_post(post, "crystals")

# for idx, post in enumerate(posts):
    
#     if idx in data['index']:continue
#     if idx % 5:time.sleep(30)
        
#     data['index'].append(idx)
#     data['date'].append(post.date)
#     data['caption'].append(post.caption)
#     data['comments'].append(post.comments)
#     pd.DataFrame(data).to_csv("posts_temp2.csv")
#     # print(idx)
# Out:
# C:\Users\wslee.2019\Anaconda3\lib\site-packages\win_unicode_console\__init__.py:31: RuntimeWarning: sys.stdin.encoding == 'utf-8', whereas sys.stdout.encoding == 'UTF-8', readline hook consumer may assume they are the same
#   readline_hook.enable(use_pyreadline=use_pyreadline)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-089f5d0d621a> in <module>
#      17
#      18 # posts = instaloader.Hashtag.from_name(L.context, "jam.stones").get_posts()
# ---> 19 posts = instaloader.Hashtag.from_name(L.context, "crystals").get_posts()
#      20
#      21 # Tracing backwards from today
#
# ~\Anaconda3\lib\site-packages\instaloader\structures.py in from_name(cls, context, name)
#    1379         # pylint:disable=protected-access
#    1380         hashtag = cls(context, {'name': name.lower()})
# -> 1381         hashtag._obtain_metadata()
# ...
