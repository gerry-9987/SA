# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_csv('JS_followers_info_0_to500.csv')

# %%
df.head()
# Out:
#    Unnamed: 0          follower  \
# 0           0         gwengwenn
# 1           1          huimin_c
# 2           2         agent_g07
# 3           3  agnestankimpheng
# 4           4          umareumm
#
#                                      no_of_followers  \
# 0  <instaloader.nodeiterator.NodeIterator object ...
# 1  <instaloader.nodeiterator.NodeIterator object ...
# 2  <instaloader.nodeiterator.NodeIterator object ...
# 3  <instaloader.nodeiterator.NodeIterator object ...
# 4  <instaloader.nodeiterator.NodeIterator object ...
#
#                                      no_of_followees  is_private      ratio  \
# 0  <instaloader.nodeiterator.NodeIterator object ...        True   6.446970
# 1  <instaloader.nodeiterator.NodeIterator object ...        True   1.202740
# 2  <instaloader.nodeiterator.NodeIterator object ...        True  29.038462
# 3  <instaloader.nodeiterator.NodeIterator object ...       False   6.940476
# ...

# %%
c_maxes = df.groupby(['follower'])["Unnamed: 0"].transform(max)
df = df.loc[df.index == c_maxes]

# %%
df.head()
# Out:
#     Unnamed: 0            follower no_of_followers no_of_followees  \
# 20          20  zima_loves_bunnies             341            1585
# 21          21       wolf_katazyna            1482            5607
# 22          22          _cara_tan_             280             553
# 23          23            ekitty27              96             175
# 24          24           pohjaslin             535             454
#
#     is_private     ratio  no_of_posts possible_candidate
# 20        True  4.648094          135                 No
# 21        True  3.783401          614                 No
# 22        True  1.975000            5                 No
# 23       False  1.822917           58                 No
# 24       False  0.848598          777                 No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 20 to 519
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          500 non-null    int64
#  1   follower            500 non-null    object
#  2   no_of_followers     500 non-null    object
#  3   no_of_followees     500 non-null    object
#  4   is_private          500 non-null    bool
#  5   ratio               500 non-null    float64
#  6   no_of_posts         500 non-null    int64
#  7   possible_candidate  500 non-null    object
# dtypes: bool(1), float64(1), int64(2), object(4)
# memory usage: 31.7+ KB

# %%
df.to_csv("JS_followers_info_0_to500_cleaned.csv", index=False)
