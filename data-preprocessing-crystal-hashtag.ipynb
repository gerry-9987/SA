# %% [markdown]
# ### 1 - Import packages

# %%
""" Package for language translation """
# !pip install deep-translator
# Out:
# Requirement already satisfied: deep-translator in c:\users\jewel\anaconda3\lib\site-packages (1.8.1)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in c:\users\jewel\anaconda3\lib\site-packages (from deep-translator) (2.24.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in c:\users\jewel\anaconda3\lib\site-packages (from deep-translator) (4.9.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jewel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\jewel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\jewel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jewel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2020.6.20)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\jewel\anaconda3\lib\site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.0.1)

# %%
import pandas as pd
import html

import re

from deep_translator import GoogleTranslator

import nltk
from nltk.corpus import wordnet
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jewel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\jewel\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jewel\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jewel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ### 2 - Import Data

# %%
insta_df = pd.read_csv("instagram_hashtag_results_17Mar_cleaned.csv")

# %%
insta_df.isnull().sum()
# Out:
# postUrl             0
# profileUrl          0
# username            0
# fullName           62
# commentCount        0
# likeCount           0
# pubDate             0
# description         3
# imgUrl            247
# postId              0
# ownerId             0
# type                0
# query               0
# timestamp           0
# location         1451
# isSidecar           0
# sidecarMedias    1313
# videoUrl         1671
# viewCount        1692
# dtype: int64

# %% [markdown]
# ### 3 - Drop rows without captions

# %%
real_insta_df = insta_df[~insta_df.description.isnull()]

# %% [markdown]
# ### 4 - Clean captions
#
# 1. Remove any HTML tags
# 2. Translate caption from other language to English
# 3. Shorten words to their basic form while keeping the original meaning
# 4. Remove stopwords so that our topic modeling will be more meaningful
# 5. Store clean captions in a new column
# 6. Store clean caption as a list of words in another new column

# %%
### 4 - Helper functions for data preprocessing
"""
Code references:
    https://pythonguides.com/remove-unicode-characters-in-python/
    https://www.kite.com/python/answers/how-to-decode-html-entities-in-python
"""
def decode_text(text):
    # remove non-ASCII characters in string
    decoded_text = text.encode('ascii', 'ignore').decode('utf-8')

    # decode HTML entities
    decoded_html = html.unescape(decoded_text)
    return ''.join([word for word in decoded_html if word.isprintable()])

"""
Code reference:
    https://medium.com/analytics-vidhya/how-to-translate-text-with-python-9d203139dcf5
"""
def translate_text(text):
    translated_text = GoogleTranslator(target='en').translate(text)
    return translated_text
"""
Code reference:
    https://catriscode.com/2021/03/02/extracting-or-removing-mentions-and-hashtags-in-tweets-using-python/
"""
# def remove_mentions(text):
#     return re.sub("@[A-Za-z0-9_]+","", text)

def remove_stopwords(words_list):
    stop_list = stopwords.words("english")
    return [word for word in words_list if word not in stop_list]

def pos_to_wordnet(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:
        return None

def lemmatize_words(word_list):
    lemmatizer = nltk.stem.WordNetLemmatizer()
    # POS (part-of-speech) tagging
    # nltk_tagged -> a list of tuples (word, pos tag)
    nltk_tagged = nltk.pos_tag(word_list)

    # returns a list of tuples of words and their wordnet_tag (after conversion from NLTK tag)
    wordnet_tagged = list(map(lambda x: (x[0], pos_to_wordnet(x[1])), nltk_tagged))

    # lemmatizing
    lemmatized_words = []
    for word, tag in wordnet_tagged:
        if tag is not None:
            # need POS tag as 2nd argument as it helps lemmatize the words more accurately
            lemmatized_words.append(lemmatizer.lemmatize(word, tag))
        elif tag in [wordnet.NOUN] or word == "lavval" or word == "newagefsg":
            lemmatized_words.append(lemmatizer.lemmatize(word))
    return lemmatized_words

def clean_original_text(text):
    text = text.lower()
    clean_list = []
    sentence_list = nltk.sent_tokenize(text)
    for sentence in sentence_list:
        decoded_sentence = decode_text(sentence)
        translated_sentence = translate_text(decoded_sentence)
        if translated_sentence is not None:
            words_list = nltk.RegexpTokenizer(r'\w+').tokenize(translated_sentence)
            lemmatized_words = lemmatize_words(words_list)
            useful_words = remove_stopwords(lemmatized_words)

            if len(useful_words) > 0:
                clean_list.extend(useful_words)
    clean_text = ' '.join(clean_list)

    return clean_text

# %%
real_insta_df["clean_description"] = real_insta_df["description"].apply(clean_original_text)
# Out:
# <ipython-input-63-923bdd44d196>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_insta_df["clean_description"] = real_insta_df["description"].apply(clean_original_text)

# %%
real_insta_df["clean_tokens"] = real_insta_df["clean_description"].apply(nltk.word_tokenize)
# Out:
# <ipython-input-67-50c480a0bd23>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   real_insta_df["clean_tokens"] = real_insta_df["clean_description"].apply(nltk.word_tokenize)

# %%
real_insta_df
# Out:
#                                        postUrl  \
# 0     https://www.instagram.com/p/CbKYWL8AuAF/
# 1     https://www.instagram.com/p/CbK9hAvhxjC/
# 2     https://www.instagram.com/p/CbKJdGUj_gg/
# 3     https://www.instagram.com/p/CbHDHKrPN1X/
# 4     https://www.instagram.com/p/CbIAdAXupdV/
# ...                                        ...
# 1913  https://www.instagram.com/p/CbK3NCerlnY/
# 1914  https://www.instagram.com/p/CbK3G15j012/
# 1915  https://www.instagram.com/p/CbK3QDTOcN8/
# 1916  https://www.instagram.com/p/CbK24RZt8UK/
# 1917  https://www.instagram.com/p/CbK2w1MDvPC/
#
#                                           profileUrl              username  \
# 0            https://www.instagram.com/leassteinwelt         leassteinwelt
# 1           https://www.instagram.com/awakenstardust        awakenstardust
# 2      https://www.instagram.com/praktijk_matricaria   praktijk_matricaria
# 3     https://www.instagram.com/nickycrystcollection  nickycrystcollection
# 4        https://www.instagram.com/sacredsoulfulshop     sacredsoulfulshop
# ...                                              ...                   ...
# 1913  https://www.instagram.com/positiveknotsjewelry  positiveknotsjewelry
# 1914       https://www.instagram.com/breezydaystudio       breezydaystudio
# 1915       https://www.instagram.com/opossum_doodles       opossum_doodles
# 1916     https://www.instagram.com/empoweredcrystals     empoweredcrystals
# 1917         https://www.instagram.com/maokaicrystal         maokaicrystal
#
#                          fullName  commentCount  likeCount  \
# 0             💎Kristall Paradies💎             9        501
# 1           Bring Love to People❤            26       1157
# 2             Praktijk Matricaria            26        181
# 3                             NaN            18       1438
# 4         Crystals &amp; Wellness             9        150
# ...                           ...           ...        ...
# 1913  🌻Positive Knots Jewelry🧘‍♀️             1         15
# 1914            Breezy Day Studio             0          3
# 1915                   Remy's art             3         15
# 1916           Empowered Crystals             0         47
# 1917                        Jason             0          1
#
#                        pubDate  \
# 0     2022-03-16T10:58:16.000Z
# 1     2022-03-16T16:23:03.000Z
# 2     2022-03-16T08:48:08.000Z
# 3     2022-03-15T03:54:59.000Z
# 4     2022-03-15T12:51:00.000Z
# ...                        ...
# 1913  2022-03-16T15:27:54.000Z
# 1914  2022-03-16T15:27:03.000Z
# 1915  2022-03-16T15:28:18.000Z
# 1916  2022-03-16T15:25:16.000Z
# 1917  2022-03-16T15:25:41.000Z
#
#                                             description  \
# 0     Wir haben schon die letzten Tage super fleißig...
# 1     Drop a 👁️ if you can relate\r\nFollow @awakens...
# 2     Spirit kwarts 💕\r\nEindelijk! Na een lange zoe...
# 3     Beautiful pink amethyst freedom from @elo.di_ ...
# 4     We’re you able to scoop up some Orca Agate las...
# ...                                                 ...
# 1913  Come visit me this Saturday at the @tacomacomm...
# 1914  March Madness SALE 40% OFF \r\n\r\n🌿Shop Link ...
# 1915  🌈 tear-drop oplaite earrings 🌈\r\n\r\nSpring s...
# 1916  A few blue kyanite rings. A wonderful cleansin...
# 1917  🌈🎉🌙⭐Super beautiful stone, crinoids fossils!  ...
#
#                                                  imgUrl               postId  \
# 0     https://scontent-yyz1-1.cdninstagram.com/v/t51...  2795153596499550000
# 1     https://scontent-yyz1-1.cdninstagram.com/v/t51...  2795317068114106400
# 2     https://scontent-yyz1-1.cdninstagram.com/v/t51...  2795088100807670000
# 3     https://scontent-yyz1-1.cdninstagram.com/v/t51...  2794215780445380000
# 4     https://scontent-yyz1-1.cdninstagram.com/v/t51...  2794485562046322700
# ...                                                 ...                  ...
# 1913  https://scontent-amt2-1.cdninstagram.com/v/t51...  2795289307310348760
# 1914  https://scontent-ams4-1.cdninstagram.com/v/t51...  2795288881485794678
# 1915  https://scontent-amt2-1.cdninstagram.com/v/t51...  2795289514350330748
# 1916  https://scontent-ams4-1.cdninstagram.com/v/t51...  2795287880224195850
# 1917                                                NaN  2795287368893920194
#
#       ...      type            query                 timestamp  \
# 0     ...     Photo        #crystals  2022-03-17T01:27:17.629Z
# 1     ...     Photo        #crystals  2022-03-17T01:27:17.629Z
# 2     ...     Photo        #crystals  2022-03-17T01:27:17.629Z
# 3     ...     Photo        #crystals  2022-03-17T01:27:17.629Z
# 4     ...     Photo        #crystals  2022-03-17T01:27:17.629Z
# ...   ...       ...              ...                       ...
# 1913  ...     Photo  #crystaljewelry  2022-03-17T02:04:53.632Z
# 1914  ...  Carousel  #crystaljewelry  2022-03-17T02:04:53.632Z
# 1915  ...     Photo  #crystaljewelry  2022-03-17T02:04:53.632Z
# 1916  ...     Photo  #crystaljewelry  2022-03-17T02:04:53.632Z
# 1917  ...     Video  #crystaljewelry  2022-03-17T02:04:53.632Z
#
#                           location isSidecar  sidecarMedias  \
# 0                              NaN     False            NaN
# 1                              NaN     False            NaN
# 2                              NaN     False            NaN
# 3                              NaN     False            NaN
# 4                 Vaughan, Ontario     False            NaN
# ...                            ...       ...            ...
# 1913  Tacoma Arts Community Center     False            NaN
# 1914   Penticton, British Columbia      True            3.0
# 1915                           NaN     False            NaN
# 1916                           NaN     False            NaN
# 1917                           NaN     False            NaN
#
#                                                videoUrl viewCount  \
# 0                                                   NaN       NaN
# 1                                                   NaN       NaN
# 2                                                   NaN       NaN
# 3                                                   NaN       NaN
# 4                                                   NaN       NaN
# ...                                                 ...       ...
# 1913                                                NaN       NaN
# 1914                                                NaN       NaN
# 1915                                                NaN       NaN
# 1916                                                NaN       NaN
# 1917  https://scontent-amt2-1.cdninstagram.com/v/t50...       7.0
#
#                                       clean_description  \
# 0     work hard past day prepare mega restock time n...
# 1     drop relatefollow awakenstardust spiritualawak...
# 2     spirit quartz finally long search find beautif...
# 3     beautiful pink amethyst freedom elo di_ druzy ...
# 4     able scoop orca agate last week dont worry sur...
# ...                                                 ...
# 1913  come visit saturday tacomacommunitycenter hill...
# 1914  march madness sale shop link breezydaystudio d...
# 1915  tear drop oplaite earring spring sale march it...
# 1916  blue kyanite ring wonderful cleansing stone cr...
# 1917  super beautiful stone crinoid fossil omg reall...
#
#                                            clean_tokens
# 0     [work, hard, past, day, prepare, mega, restock...
# 1     [drop, relatefollow, awakenstardust, spiritual...
# 2     [spirit, quartz, finally, long, search, find, ...
# 3     [beautiful, pink, amethyst, freedom, elo, di_,...
# 4     [able, scoop, orca, agate, last, week, dont, w...
# ...                                                 ...
# 1913  [come, visit, saturday, tacomacommunitycenter,...
# 1914  [march, madness, sale, shop, link, breezydayst...
# 1915  [tear, drop, oplaite, earring, spring, sale, m...
# 1916  [blue, kyanite, ring, wonderful, cleansing, st...
# 1917  [super, beautiful, stone, crinoid, fossil, omg...
#
# [1915 rows x 21 columns]

# %% [markdown]
# ### 5 - Save cleaned data to csv file

# %%
real_insta_df.to_csv("instagram_crystal_hashtag_clean.csv")
