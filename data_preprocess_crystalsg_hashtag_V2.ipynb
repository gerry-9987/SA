# %% [markdown]
# ### 1 - Import packages

# %%
""" Package for language translation """
# !pip install deep-translator
# Out:
# Requirement already satisfied: deep-translator in c:\users\jewel\anaconda3\lib\site-packages (1.8.1)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in c:\users\jewel\anaconda3\lib\site-packages (from deep-translator) (2.24.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in c:\users\jewel\anaconda3\lib\site-packages (from deep-translator) (4.9.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\jewel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jewel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jewel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\jewel\anaconda3\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.10)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\jewel\anaconda3\lib\site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.0.1)

# %%
import pandas as pd
import html

import re

from deep_translator import GoogleTranslator

import nltk
from nltk.corpus import wordnet
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jewel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\jewel\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jewel\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jewel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ### 2 - Import Data

# %%
insta_df = pd.read_csv("instagram_hashtag_results_crystalsg_cleaned.csv")

# %%
insta_df.isnull().sum()
# Out:
# postUrl             0
# profileUrl          0
# username            0
# fullName           82
# commentCount        0
# likeCount           0
# pubDate             0
# description         0
# imgUrl             98
# postId              0
# ownerId             0
# type                0
# query               0
# timestamp           0
# location         1606
# isSidecar           0
# sidecarMedias    1099
# videoUrl         1900
# viewCount        1901
# dtype: int64

# %% [markdown]
# ### 3 - Drop rows without captions

# %%
real_insta_df = insta_df[~insta_df.description.isnull()]

# %% [markdown]
# ### 4 - Clean captions
#
# 1. Replace `\n` and `\t` with space, and remove any HTML tags
# 2. Translate caption from other language to English
# 3. Remove mentions from caption
# 4. Remove hashtags from caption
# 5. Shorten words to their basic form while keeping the original meaning
# 6. Remove stopwords so that our topic modeling will be more meaningful
# 7. Store clean captions in a new column
# 8. Store clean caption as a list of words in another new column

# %%
### 4 - Helper functions for data preprocessing
"""
Code references:
    https://pythonguides.com/remove-unicode-characters-in-python/
    https://www.kite.com/python/answers/how-to-decode-html-entities-in-python
"""
def decode_text(text):
    # remove non-ASCII characters in string
    decoded_text = text.encode('ascii', 'ignore').decode('utf-8')
    spaced_text = re.sub("\n", " ", decoded_text)
    spaced_text2 = re.sub("\t", " ", spaced_text)
    # decode HTML entities
    decoded_html = html.unescape(spaced_text2)
    words = [word for word in decoded_html if word.isprintable()]
    return ''.join([word for word in decoded_html if word.isprintable()])

"""
Code reference:
    https://medium.com/analytics-vidhya/how-to-translate-text-with-python-9d203139dcf5
"""
def translate_text(text):
    translated_text = GoogleTranslator(target='en').translate(text)
    return translated_text
"""
Code reference:
    https://catriscode.com/2021/03/02/extracting-or-removing-mentions-and-hashtags-in-tweets-using-python/
"""
def remove_mentions(text):
    return re.sub("@[A-Za-z0-9_]+","", text)

def remove_hashtags(text):
    return re.sub("#[A-Za-z0-9_]+", "", text)

def remove_stopwords(words_list):
    stop_list = stopwords.words("english")
    return [word for word in words_list if word not in stop_list]

def pos_to_wordnet(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:
        return None

def lemmatize_words(word_list):
    lemmatizer = nltk.stem.WordNetLemmatizer()
    # POS (part-of-speech) tagging
    # nltk_tagged -> a list of tuples (word, pos tag)
    nltk_tagged = nltk.pos_tag(word_list)

    # returns a list of tuples of words and their wordnet_tag (after conversion from NLTK tag)
    wordnet_tagged = list(map(lambda x: (x[0], pos_to_wordnet(x[1])), nltk_tagged))

    # lemmatizing
    lemmatized_words = []
    for word, tag in wordnet_tagged:
        if tag is not None:
            # need POS tag as 2nd argument as it helps lemmatize the words more accurately
            lemmatized_words.append(lemmatizer.lemmatize(word, tag))
        elif tag in [wordnet.NOUN] or word == "lavval" or word == "newagefsg":
            lemmatized_words.append(lemmatizer.lemmatize(word))
    return lemmatized_words

# %% [markdown]
# ## V2 - Remove mentions and hashtags from posts

# %%
def clean_original_text(text):
    text = text.lower()
    clean_list = []
    sentence_list = nltk.sent_tokenize(text)
    for sentence in sentence_list:
        decoded_sentence = decode_text(sentence)
        translated_sentence = translate_text(decoded_sentence)
        if translated_sentence is not None:
            mentionless_sentence = remove_mentions(translated_sentence)
            tagless_sentence = remove_hashtags(mentionless_sentence)
            words_list = nltk.RegexpTokenizer(r'\w+').tokenize(tagless_sentence)
            lemmatized_words = lemmatize_words(words_list)
            useful_words = remove_stopwords(lemmatized_words)

            if len(useful_words) > 0:
                clean_list.extend(useful_words)
    clean_text = ' '.join(clean_list)

    return clean_text

# %%
real_insta_df["clean_description"] = real_insta_df["description"].apply(clean_original_text)

# %%
real_insta_df["clean_tokens"] = real_insta_df["clean_description"].apply(nltk.word_tokenize)

# %%
real_insta_df
# Out:
#                                        postUrl  \
# 0     https://www.instagram.com/p/CaJQO5HPHO1/
# 1     https://www.instagram.com/p/CZMdip8PCzX/
# 2     https://www.instagram.com/p/CZviYgxvmz7/
# 3     https://www.instagram.com/p/CUaL0oNPhEm/
# 4     https://www.instagram.com/p/CW76Q2ZPwI9/
# ...                                        ...
# 1993  https://www.instagram.com/p/Ca5WLPNBANU/
# 1994  https://www.instagram.com/p/Ca5WD0EBxVw/
# 1995  https://www.instagram.com/p/Ca5UPA2hVWG/
# 1996  https://www.instagram.com/p/Ca5QCWShv5v/
# 1997  https://www.instagram.com/p/Ca5Pd2QhAqA/
#
#                                           profileUrl              username  \
# 0           https://www.instagram.com/petalsofarosez        petalsofarosez
# 1             https://www.instagram.com/princessezyt          princessezyt
# 2     https://www.instagram.com/moonwanderer.est2020  moonwanderer.est2020
# 3              https://www.instagram.com/crystalliac           crystalliac
# 4           https://www.instagram.com/rehauscrystals        rehauscrystals
# ...                                              ...                   ...
# 1993   https://www.instagram.com/crystal_stone_agate   crystal_stone_agate
# 1994   https://www.instagram.com/crystal_stone_agate   crystal_stone_agate
# 1995  https://www.instagram.com/internationalgemshop  internationalgemshop
# 1996     https://www.instagram.com/ervina_crystal123     ervina_crystal123
# 1997     https://www.instagram.com/ervina_crystal123     ervina_crystal123
#
#                      fullName  commentCount  likeCount  \
# 0                  Amanda Low            16        910
# 1     Triple R Mummy Princess           102        527
# 2            moonwandererclub             9        711
# 3           💫 Crystals Shop 💫             5        131
# 4              RehausCrystals           109      51204
# ...                       ...           ...        ...
# 1993      Crystal_Stone_Agate             0          5
# 1994      Crystal_Stone_Agate             0          6
# 1996  https://scontent-iad3-2.cdninstagram.com/v/t51...  2790331974249021039
# 1997  https://scontent-iad3-2.cdninstagram.com/v/t51...  2790329465954372224
#
#       ...      type       query                 timestamp  \
# 0     ...     Photo  #crystalsg  2022-03-18T04:48:25.073Z
# 1     ...  Carousel  #crystalsg  2022-03-18T04:48:25.073Z
# 2     ...  Carousel  #crystalsg  2022-03-18T04:48:25.073Z
# 3     ...  Carousel  #crystalsg  2022-03-18T04:48:25.073Z
# 4     ...  Carousel  #crystalsg  2022-03-18T04:48:25.074Z
# ...   ...       ...         ...                       ...
# 1993  ...     Photo  #crystalsg  2022-03-18T04:53:04.413Z
# 1994  ...     Photo  #crystalsg  2022-03-18T04:53:04.413Z
# 1995  ...     Photo  #crystalsg  2022-03-18T04:53:04.413Z
# 1996  ...     Photo  #crystalsg  2022-03-18T04:53:04.413Z
# 1997  ...  Carousel  #crystalsg  2022-03-18T04:53:04.413Z
#
#                                         location isSidecar  sidecarMedias  \
# 0      Singapore / Singapura / 新加坡 / சிங்கப்பூர்     False            NaN
# 1     PARKROYAL COLLECTION Marina Bay, Singapore      True            7.0
# 2                                 Atlantic Ocean      True            3.0
# 3                                      Singapore      True            9.0
# 4                                            NaN      True            4.0
# ...                                          ...       ...            ...
# 1993                                         NaN     False            NaN
# 1994                                         NaN     False            NaN
# 1995                          Peshawar, Pakistan     False            NaN
# 1996                                         NaN     False            NaN
# 1997                                         NaN      True            2.0
#
#       videoUrl viewCount                                  clean_description  \
# 0          NaN       NaN  deserve single shot night appreciate beauty co...
# 1          NaN       NaN  cny get love one new pretty crystal water bott...
# 2          NaN       NaN  deep ocean feature gemmy teal blue purple fluo...
# 3          NaN       NaN  let go green preview join saturday night octob...
# 4          NaN       NaN  pink gemmy rise quartz tumble literal candy ri...
# ...        ...       ...                                                ...
# 1993       NaN       NaN                                                 dm
# 1994       NaN       NaN                                                 dm
# 1995       NaN       NaN  band bumblebee calcite spheres available ship ...
# 1996       NaN       NaN     plume agate moon carve available sale dm order
# 1997       NaN       NaN  pink lace agate bat carve available sale dm order
#
#                                            clean_tokens
# 0     [deserve, single, shot, night, appreciate, bea...
# 1     [cny, get, love, one, new, pretty, crystal, wa...
# 2     [deep, ocean, feature, gemmy, teal, blue, purp...
# 3     [let, go, green, preview, join, saturday, nigh...
# 4     [pink, gemmy, rise, quartz, tumble, literal, c...
# ...                                                 ...
# 1993                                               [dm]
# 1994                                               [dm]
# 1995  [band, bumblebee, calcite, spheres, available,...
# 1996  [plume, agate, moon, carve, available, sale, d...
# 1997  [pink, lace, agate, bat, carve, available, sal...
#
# [1998 rows x 21 columns]

# %% [markdown]
# ### 5 - Save cleaned data to csv file

# %%
real_insta_df.to_csv("instagram_crystalsg_hashtag_clean_new.csv")
