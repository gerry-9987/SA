# %%
import instaloader
from decouple import config
from IPython.display import clear_output
import pandas as pd
import time
# Out:
# C:\Users\wslee.2019\Anaconda3\lib\site-packages\win_unicode_console\__init__.py:31: RuntimeWarning: sys.stdin.encoding == 'utf-8', whereas sys.stdout.encoding == 'UTF-8', readline hook consumer may assume they are the same
#   readline_hook.enable(use_pyreadline=use_pyreadline)

# %%
# change code accordingly & add insta credentials to .env file

accounts = ['',1,2,3]
account = accounts[2]
USER = config('USER')
PASSWORD = config('PASSWORD')
# print(USER)
# print(PASSWORD)
L = instaloader.Instaloader()
L.login(USER, PASSWORD)

# %%
js_followers = pd.read_csv('followers.csv')['0']

# change the start & end index
start = 2109
end = 3000 #4000
file_name = f'edges_{start}_to{end}'

# swap the comments below if running code the first time
try:
    edges = pd.read_csv(f'{file_name}.csv')
    data = edges[['from','to']].to_dict('list')
    print("csv found")
    edges['from'].value_counts()
    x=edges.groupby('from')[['to']].count().reset_index().sort_values(by='to')
    print("accounts scraped (not private or rejected):", x[x['to']>1]['to'].count())
except:
    data = {'from':[], 'to':[]}
    print('csv not found, created new one')
# Out:
# csv not found, created new one

# %%
exceptions = {}
account_pointer = 0

# stats
privates = 0
no_posts = 0
bad_ratio = 0

while True:
    for idx, username in enumerate(js_followers):

        # change the number below
        if idx == end:break
        if idx < start:continue
        if username in data['from']:continue

        # Loader
        try:
            profile = instaloader.Profile.from_username(L.context, username)
            following = profile.get_followees()
        except Exception as e:
            if e in exceptions.keys():exceptions[e]+=1
            else:exceptions[e]=1

        # variables
        is_private = profile.is_private
        no_posts = profile.mediacount
        ratio = profile.followees/(profile.followers or not profile.followers)
        print(f'doing {username} who is following {profile.followees} accounts')
        print(f"Private:{is_private} Posts:{no_posts} Ratio:{round(ratio,1)}")

        # checks
        if is_private:privates+=1
        if no_posts==0:no_posts+=1
        if ratio>10:bad_ratio+=1
        if no_posts==0 or ratio > 10:
            data['from'].append(username)
            data['to'].append("jam.stones")
            continue

        # collect data
        for follower in following:
            data['from'].append(username)
            data['to'].append(follower.username)

        # add JS edge
        data['from'].append(username)
        data['to'].append("jam.stones")

        # save file
        pd.DataFrame(data).to_csv(f"{file_name}.csv")

        print(f'finished js follower {idx}/{len(js_followers)}')
# Out:
# doing crystal_shop8686 who is following 5637 accounts
# Private:False Posts:411 Ratio:1.2
# finished js follower 2109/13404
# doing jtdidi who is following 1276 accounts
# Private:True Posts:200 Ratio:4.6
# finished js follower 2110/13404
# doing oolongcrystals_ who is following 2666 accounts
# Private:False Posts:73 Ratio:4.6
# finished js follower 2111/13404
# doing grilledchickensalad_ who is following 98 accounts
# Private:True Posts:156 Ratio:10.9
# doing lovedust_ who is following 806 accounts
# Private:True Posts:2 Ratio:2.7
# finished js follower 2113/13404
# doing leegailz who is following 301 accounts
# Private:True Posts:51 Ratio:3.0
# finished js follower 2114/13404
# doing keaipingguo who is following 128 accounts
# Private:True Posts:30 Ratio:8.0
# finished js follower 2115/13404
# doing joycekum who is following 344 accounts
# Private:True Posts:478 Ratio:1.6
# finished js follower 2116/13404
# doing teohweesan who is following 1060 accounts
# Private:True Posts:791 Ratio:117.8
# doing jialijace who is following 858 accounts
# Private:False Posts:1809 Ratio:3.9
# finished js follower 2118/13404
# doing dianatpk88 who is following 1534 accounts
# Private:False Posts:178 Ratio:4.5
#
# Too many queries in the last time. Need to wait 175 seconds, until 21:34.
# finished js follower 2119/13404
# doing cherzlelx who is following 257 accounts
# Private:True Posts:3 Ratio:42.8
# doing jnkeuken who is following 36 accounts
# Private:False Posts:149 Ratio:0.3
# finished js follower 2121/13404
# doing stateofbinky who is following 776 accounts
# Private:True Posts:469 Ratio:2.0
# finished js follower 2122/13404
# doing lemon.squa3h who is following 543 accounts
# Private:False Posts:14 Ratio:1.5
# finished js follower 2123/13404
# doing saidah.saini who is following 1182 accounts
# Private:True Posts:1680 Ratio:1.9
# finished js follower 2124/13404
# doing aeneymoly who is following 1167 accounts
# Private:False Posts:103 Ratio:4.4
# finished js follower 2125/13404
# doing wennxuann who is following 318 accounts
# Private:True Posts:109 Ratio:1.7
# finished js follower 2126/13404
# doing alewxb who is following 354 accounts
# Private:True Posts:0 Ratio:9.3
# finished js follower 2127/13404
# doing resin_escape who is following 506 accounts
# Private:False Posts:275 Ratio:3.5
# finished js follower 2128/13404
# doing tanyensing who is following 62 accounts
# Private:True Posts:10 Ratio:0.7
# finished js follower 2129/13404
# doing ai_ling0 who is following 1215 accounts
# Private:False Posts:168 Ratio:0.8
# finished js follower 2130/13404
# doing almj7896 who is following 97 accounts
# Private:False Posts:108 Ratio:1.6
# finished js follower 2131/13404
# doing limited.crystal15 who is following 309 accounts
# Private:False Posts:2 Ratio:5.8
# finished js follower 2132/13404
# doing adeline.teoh who is following 6157 accounts
# Private:True Posts:769 Ratio:11.0
# doing puteri_ishaaa who is following 421 accounts
# Private:True Posts:5 Ratio:2.9
# finished js follower 2134/13404
# doing prunellayup who is following 557 accounts
# Private:True Posts:0 Ratio:1.0
# finished js follower 2135/13404
# doing koizumi_mikorin who is following 309 accounts
# Private:False Posts:0 Ratio:1.7
# finished js follower 2136/13404
# doing huijinhj who is following 1382 accounts
# Private:True Posts:408 Ratio:4.0
# finished js follower 2137/13404
# doing lianne.tkl who is following 25 accounts
# Private:True Posts:0 Ratio:1.2
# finished js follower 2138/13404
# doing maggieqq_shine who is following 332 accounts
# Private:True Posts:50 Ratio:3.3
# finished js follower 2139/13404
# doing minnie_one23 who is following 109 accounts
# Private:True Posts:602 Ratio:109.0
# doing thebeautyofpollypockets who is following 813 accounts
# Private:True Posts:26 Ratio:7.2
# finished js follower 2141/13404
# doing blingnsplitz who is following 7498 accounts
# Private:False Posts:1069 Ratio:1.9
#
# Too many queries in the last time. Need to wait 132 seconds, until 21:45.
# finished js follower 2142/13404
# doing 1996olivi who is following 1523 accounts
# Private:True Posts:10 Ratio:5.4
# finished js follower 2143/13404
# doing juneejuney who is following 2633 accounts
# Private:False Posts:2329 Ratio:0.6
# finished js follower 2144/13404
# doing 1004obsessed who is following 1553 accounts
# Private:True Posts:8219 Ratio:19.2
# doing missietsang who is following 346 accounts
# Private:False Posts:0 Ratio:2.1
# finished js follower 2146/13404
# doing deareloise who is following 133 accounts
# Private:False Posts:49 Ratio:1.0
# finished js follower 2147/13404
# doing geraldineljt who is following 747 accounts
# Private:True Posts:687 Ratio:3.6
# finished js follower 2148/13404
# doing lollipoptwinkle who is following 385 accounts
# Private:True Posts:322 Ratio:5.9
# finished js follower 2149/13404
# doing itsangewthing who is following 1485 accounts
# Private:True Posts:1092 Ratio:3.8
# finished js follower 2150/13404
# doing pikalexa_ who is following 909 accounts
# Private:False Posts:1093 Ratio:1.5
# finished js follower 2151/13404
# doing ting5935 who is following 73 accounts
# Private:False Posts:0 Ratio:1.7
# finished js follower 2152/13404
# doing aarthi1212 who is following 768 accounts
# Private:True Posts:695 Ratio:3.8
# finished js follower 2153/13404
# doing lxinhuii who is following 837 accounts
# Private:True Posts:329 Ratio:1.2
# finished js follower 2154/13404
# doing tanemilin who is following 57 accounts
# Private:True Posts:517 Ratio:2.2
# finished js follower 2155/13404
# doing tashaxlow who is following 937 accounts
# Private:True Posts:363 Ratio:1.8
# finished js follower 2156/13404
# doing mysweeeetlife who is following 490 accounts
# Private:True Posts:500 Ratio:1.3
# finished js follower 2157/13404
# doing pandamea_yuki who is following 973 accounts
# Private:False Posts:72 Ratio:1.3
#
# Too many queries in the last time. Need to wait 86 seconds, until 21:57.
# finished js follower 2158/13404
# doing nimamaflyaway who is following 124 accounts
# Private:True Posts:241 Ratio:7.3
# finished js follower 2159/13404
# doing rainbowofdreamz who is following 315 accounts
# Private:True Posts:438 Ratio:6.2
# finished js follower 2160/13404
# doing justthewayyouare12 who is following 515 accounts
# Private:True Posts:45 Ratio:11.4
# doing annhohohocy who is following 3111 accounts
# Private:True Posts:15 Ratio:9.5
# finished js follower 2162/13404
# doing nophee168 who is following 2084 accounts
# Private:False Posts:425 Ratio:4.1
# finished js follower 2163/13404
# doing jlcrystalsnfragrance.sg who is following 96 accounts
# Private:False Posts:54 Ratio:1.1
# finished js follower 2164/13404
# doing esthrgohh who is following 4137 accounts
# Private:True Posts:0 Ratio:4137.0
# doing wai_l3ng who is following 466 accounts
# Private:True Posts:127 Ratio:10.1
# doing yenli_jerica who is following 21 accounts
# Private:True Posts:0 Ratio:7.0
# finished js follower 2167/13404
# doing riannelien who is following 1696 accounts
# Private:True Posts:906 Ratio:5.4
# finished js follower 2168/13404
# doing tan_y2 who is following 284 accounts
# Private:True Posts:73 Ratio:6.9
# finished js follower 2169/13404
# doing sihui_4 who is following 731 accounts
# Private:True Posts:929 Ratio:12.8
# doing charmshealthyeats who is following 363 accounts
# Private:False Posts:714 Ratio:0.8
# finished js follower 2171/13404
# JSON Query to heyitssjunn/feed/: 404 Not Found [retrying; skip with ^C]
# JSON Query to heyitssjunn/feed/: 404 Not Found [retrying; skip with ^C]
# doing heyitssjunn who is following 363 accounts
# Private:False Posts:714 Ratio:0.8
# finished js follower 2172/13404
# doing the_blurfaerie who is following 522 accounts
# Private:False Posts:47 Ratio:1.8
# finished js follower 2173/13404
# doing zannloh who is following 340 accounts
# Private:False Posts:7 Ratio:0.7
# finished js follower 2174/13404
# doing sylvia7an who is following 482 accounts
# Private:True Posts:854 Ratio:2.2
# finished js follower 2175/13404
# doing leiapixel who is following 358 accounts
# Private:True Posts:330 Ratio:358.0
# doing thethiang who is following 2041 accounts
# Private:False Posts:1839 Ratio:2.0
# finished js follower 2177/13404
# doing sherrine1314 who is following 815 accounts
# Private:True Posts:1647 Ratio:3.9
# finished js follower 2178/13404
# doing crystals_wholesaler who is following 5360 accounts
# Private:False Posts:710 Ratio:3.0
# finished js follower 2179/13404
# doing twinkleglint who is following 850 accounts
# Private:True Posts:353 Ratio:8.1
# finished js follower 2180/13404
# doing ronaldkuik who is following 348 accounts
# Private:True Posts:430 Ratio:2.3
# finished js follower 2181/13404
# doing june_happi who is following 187 accounts
# Private:True Posts:30 Ratio:2.9
# finished js follower 2182/13404
# doing janepangkoh who is following 323 accounts
# Private:True Posts:183 Ratio:2.7
# finished js follower 2183/13404
# doing 7.ing.ting who is following 397 accounts
# Private:True Posts:381 Ratio:2.5
# finished js follower 2184/13404
# doing nsaiyidahba who is following 1023 accounts
# Private:True Posts:127 Ratio:3.5
# finished js follower 2185/13404
# doing flatsoft.healthy who is following 6615 accounts
# Private:False Posts:146 Ratio:0.4
# finished js follower 2186/13404
# doing almightybrina who is following 468 accounts
# Private:True Posts:275 Ratio:1.6
# finished js follower 2187/13404
# doing gracee.gohh who is following 741 accounts
# Private:True Posts:133 Ratio:4.3
# finished js follower 2188/13404
# doing sxirxhh who is following 1526 accounts
# Private:True Posts:0 Ratio:2.8
# finished js follower 2189/13404
# doing icandiw who is following 588 accounts
# Private:True Posts:120 Ratio:39.2
# doing reihan8664 who is following 2714 accounts
# Private:False Posts:1 Ratio:9.5
# finished js follower 2191/13404
# doing kachiang27 who is following 333 accounts
# Private:True Posts:59 Ratio:5.6
# finished js follower 2192/13404
# doing lorleepop who is following 982 accounts
# Private:True Posts:106 Ratio:4.8
# finished js follower 2193/13404
# doing afiqahishek who is following 1693 accounts
# Private:False Posts:44 Ratio:1.4
# finished js follower 2194/13404
# doing seafoamagick who is following 369 accounts
# Private:False Posts:3 Ratio:1.1
# finished js follower 2195/13404
# doing kkpp06 who is following 118 accounts
# Private:True Posts:0 Ratio:14.8
# doing jingyijanice.lee who is following 124 accounts
# Private:True Posts:27 Ratio:1.4
# finished js follower 2197/13404
# doing divinelovekrystle who is following 1342 accounts
# Private:True Posts:1913 Ratio:29.2
# doing ngvell who is following 1011 accounts
# Private:False Posts:0 Ratio:4.7
# finished js follower 2199/13404
# doing deafyza who is following 1373 accounts
# Private:True Posts:98 Ratio:18.1
# doing charmysays_hello who is following 393 accounts
# Private:True Posts:190 Ratio:6.4
# finished js follower 2201/13404
# doing debrachenhy who is following 2277 accounts
# Private:True Posts:216 Ratio:22.1
# doing lyviadearie who is following 809 accounts
# Private:False Posts:2010 Ratio:1.4
# finished js follower 2203/13404
# doing yadventurer13 who is following 992 accounts
# Private:True Posts:904 Ratio:5.2
# finished js follower 2204/13404
# doing leecynbei who is following 1042 accounts
# Private:False Posts:143 Ratio:3.1
# finished js follower 2205/13404
# doing yixxlee who is following 377 accounts
# Private:True Posts:47 Ratio:1.9
# finished js follower 2206/13404
# doing eileen3888 who is following 156 accounts
# Private:True Posts:3 Ratio:1.1
# finished js follower 2207/13404
# doing jazzmine_l who is following 999 accounts
# Private:True Posts:166 Ratio:0.8
# finished js follower 2208/13404
# doing xinny_hx who is following 188 accounts
# Private:True Posts:28 Ratio:4.9
# finished js follower 2209/13404
# doing lydiaoly who is following 744 accounts
# Private:True Posts:23 Ratio:4.7
# finished js follower 2210/13404
# doing lilingglai who is following 640 accounts
# Private:True Posts:902 Ratio:2.1
# finished js follower 2211/13404
# doing honeybeeprincess1707 who is following 1715 accounts
# Private:True Posts:17 Ratio:3.1
# finished js follower 2212/13404
# doing crlcheah who is following 809 accounts
# Private:True Posts:22 Ratio:25.3
# doing maylingcraft who is following 443 accounts
# Private:False Posts:14 Ratio:6.6
# finished js follower 2214/13404
# doing hellokittybayley who is following 650 accounts
# Private:True Posts:0 Ratio:650.0
# doing queklihiang who is following 890 accounts
# Private:False Posts:356 Ratio:2.0
# finished js follower 2216/13404
# doing j.crystalclear_ who is following 898 accounts
# Private:False Posts:120 Ratio:2.3
# finished js follower 2217/13404
# doing 0432del who is following 1234 accounts
# Private:True Posts:17 Ratio:13.9
# doing tiredofphony who is following 3495 accounts
# Private:True Posts:3095 Ratio:5.4
# finished js follower 2219/13404
# doing vernice.zhang who is following 665 accounts
# Private:False Posts:341 Ratio:0.2
# finished js follower 2220/13404
# doing priscteo who is following 1010 accounts
# Private:True Posts:38 Ratio:3.7
# finished js follower 2221/13404
# doing br3nda201 who is following 1762 accounts
# Private:False Posts:479 Ratio:1.8
# finished js follower 2222/13404
# doing joannapplee who is following 703 accounts
# Private:True Posts:28 Ratio:2.9
# finished js follower 2223/13404
# doing charlottzqy who is following 471 accounts
# Private:True Posts:664 Ratio:4.1
# finished js follower 2224/13404
# doing amandaatyj who is following 2115 accounts
# Private:True Posts:460 Ratio:4.5
# finished js follower 2225/13404
# doing linettelim who is following 1102 accounts
# Private:True Posts:3 Ratio:9.0
# finished js follower 2226/13404
# doing reginepw who is following 1012 accounts
# Private:True Posts:1342 Ratio:3.4
# finished js follower 2227/13404
# doing lixiannnnn_ who is following 509 accounts
# Private:True Posts:210 Ratio:1.1
# finished js follower 2228/13404
# doing ag_cristais who is following 4885 accounts
# Private:False Posts:57 Ratio:1.2
#
# Too many queries in the last time. Need to wait 15 seconds, until 22:41.
# JSON Query to graphql/query: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:   24   26   38   43   46   90
#  * 58712303d941c6855d4e888c5f0cd22f:  183  199  341  380  503 1005
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 6 seconds, at 22:41.
# JSON Query to graphql/query: 429 Too Many Requests [retrying; skip with ^C]
# Number of requests within last 10/11/20/22/30/60 minutes grouped by type:
#                               other:   24   26   38   43   45   90
#  * 58712303d941c6855d4e888c5f0cd22f:  181  198  341  379  503 1005
# Instagram responded with HTTP error "429 - Too Many Requests". Please
# do not run multiple instances of Instaloader in parallel or within
# short sequence. Also, do not use any Instagram App while Instaloader
# is running.
# The request will be retried in 9 seconds, at 22:41.
# ---------------------------------------------------------------------------
# TooManyRequestsException                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     348             if resp.status_code == 429:
# --> 349                 raise TooManyRequestsException("429 Too Many Requests")
#     350             if resp.status_code != 200:
#
# TooManyRequestsException: 429 Too Many Requests
#
# During handling of the above exception, another exception occurred:
#
# TooManyRequestsException                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     348             if resp.status_code == 429:
# --> 349                 raise TooManyRequestsException("429 Too Many Requests")
#     350             if resp.status_code != 200:
#
# TooManyRequestsException: 429 Too Many Requests
#
# During handling of the above exception, another exception occurred:
#
# TooManyRequestsException                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     348             if resp.status_code == 429:
# --> 349                 raise TooManyRequestsException("429 Too Many Requests")
#     350             if resp.status_code != 200:
#
# TooManyRequestsException: 429 Too Many Requests
#
# The above exception was the direct cause of the following exception:
#
# ConnectionException                       Traceback (most recent call last)
# <ipython-input-4-80cdc15836f6> in <module>
#      40
#      41         # collect data
# ---> 42         for follower in following:
#      43             data['from'].append(username)
#      44             data['to'].append(follower.username)
#
# ~\Anaconda3\lib\site-packages\instaloader\nodeiterator.py in __next__(self)
#     133             return item
#     134         if self._data['page_info']['has_next_page']:
# --> 135             query_response = self._query(self._data['page_info']['end_cursor'])
#     136             if self._data['edges'] != query_response['edges']:
#     137                 page_index, data = self._page_index, self._data
#
# ~\Anaconda3\lib\site-packages\instaloader\nodeiterator.py in _query(self, after)
#      99         try:
#     100             data = self._edge_extractor(
# --> 101                 self._context.graphql_query(
#     102                     self._query_hash, {**self._query_variables, **pagination_variables}, self._query_referer
#     103                 )
#
# ~\Anaconda3\lib\site-packages\instaloader\instaloadercontext.py in graphql_query(self, query_hash, variables, referer, rhx_gis)
#     426                 tmpsession.headers['x-instagram-gis'] = x_instagram_gis
#     427
# --> 428             resp_json = self.get_json('graphql/query',
#     429                                       params={'query_hash': query_hash,
#     430                                               'variables': variables_json},
#
# ~\Anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     392                     if is_other_query:
#     393                         self._rate_controller.handle_429('other')
# --> 394                 return self.get_json(path=path, params=params, host=host, session=sess, _attempt=_attempt + 1)
#     395             except KeyboardInterrupt:
#     396                 self.error("[skipped by user]", repeat_at_end=False)
#
# ~\Anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     392                     if is_other_query:
#     393                         self._rate_controller.handle_429('other')
# --> 394                 return self.get_json(path=path, params=params, host=host, session=sess, _attempt=_attempt + 1)
#     395             except KeyboardInterrupt:
#     396                 self.error("[skipped by user]", repeat_at_end=False)
#
# ~\Anaconda3\lib\site-packages\instaloader\instaloadercontext.py in get_json(self, path, params, host, session, _attempt)
#     382                     raise QueryReturnedNotFoundException(error_string) from err
#     383                 else:
# --> 384                     raise ConnectionException(error_string) from err
#     385             self.error(error_string + " [retrying; skip with ^C]", repeat_at_end=False)
#     386             try:
#
# ConnectionException: JSON Query to graphql/query: 429 Too Many Requests
